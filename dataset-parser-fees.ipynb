# %%
import gzip
import pickle
import os
from tqdm.notebook import tqdm
import pandas as pd
#from web3 import Web3
import web3
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /Users/kris/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
path_dir = './data/'
os.makedirs(path_dir, exist_ok=True)

# %%
file_fees = 'txs_fees.csv.gz'
swap_df = pd.read_csv(path_dir+'/'+file_fees,
                        sep=',', compression='gzip')
swap_df.head()
# Out:
#                                      transactionHash  blockNumber  \
# 0  0xe2776359e192a554f33f736c7e31d0c950a2842151d2...      8600000
# 1  0xf3f5c1d29a09e65e712f54dd9b6cec7a9f56dfd3af52...      8600001
# 2  0xac2306a5ebe519d4debbbebbf6f5d9c9d007dbf09243...      8600006
# 3  0xc4c8a7095a8361aeda3c1583480a3d6dd16a49dc5fda...      8600011
# 4  0xeaf2425c65119702f3bc982be543bff9a455912e38d6...      8600021
#
#    transactionIndex                                      sender  \
# 0                 0  0x1e45995a814db6a84b70aeece985779639c7deff
# 1                 1  0x317b2249c1d02e252869db64cb6e34941282b3c1
# 2                 0  0x025e5996941f9aece41631554991ccd263bdde6a
# 3                 0  0x50b68702548fd2bfde1c4c02129cb2ce7067b2c4
# 4                 0  0x66e41cae81ee95d56da2d7d14164119e948bd64f
#
#                                      receiver  gasUsed  effectiveGasPrice  \
# 0  0x2da10a1e27bf85cedd8ffb1abbe97e53391c0295  1147959          250000000
# ...

# %%
file1 = 'zkSwap-Uniswap-V2-WBTC-ETH_Swap.csv.gz'
swap1_df = pd.read_csv(path_dir+'/'+file1,
                        sep=',', compression='gzip')
swap1_df.head()
# Out:
#    Unnamed: 0  blockNumber                                    transactionHash  \
# 0           0      7804646  0x3c45fb6345d2b1b08e42c7f1d0c1628d958e82024e5d...
# 1           1      7928516  0xcb06bdfc889a060328520612e8775c310888a1e8fd30...
# 2           2      7938892  0x96833661dff7d2aa3894b02ed4d9a45340c3cddce53d...
# 3           3      7990324  0x434608460b2f4e574095d38bf8cc56b325d87483c071...
# 4           4      7990465  0xb2f41ff0578f244d148d3152ec78d1860f59c153c456...
#
#                                       address  transactionIndex  logIndex  \
# 0  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 4        26
# 1  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 0         5
# 2  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 0         5
# 3  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                10        62
# 4  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 3        30
#
# ...

# %%
swap2_df = swap1_df.merge(swap_df[['transactionHash','gasUsed','effectiveGasPrice', 'fees', 'status']], on='transactionHash', how='left')

swap2_df.head()
# Out:
#    Unnamed: 0  blockNumber                                    transactionHash  \
# 0           0      7804646  0x3c45fb6345d2b1b08e42c7f1d0c1628d958e82024e5d...
# 1           1      7928516  0xcb06bdfc889a060328520612e8775c310888a1e8fd30...
# 2           2      7938892  0x96833661dff7d2aa3894b02ed4d9a45340c3cddce53d...
# 3           3      7990324  0x434608460b2f4e574095d38bf8cc56b325d87483c071...
# 4           4      7990465  0xb2f41ff0578f244d148d3152ec78d1860f59c153c456...
#
#                                       address  transactionIndex  logIndex  \
# 0  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 4        26
# 1  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 0         5
# 2  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 0         5
# 3  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                10        62
# 4  0xe5716ad6873f7d9919b0a72f5b33570f77c1a615                 3        30
#
# ...

# %%
len(swap2_df)
# Out:
# 5869

# %%
swap2_df.to_csv(path_dir+'/'+'zkSwap-Uniswap-V2-WBTC-ETH_Swap_fees.csv', sep=',')
